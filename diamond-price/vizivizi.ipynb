# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('./data/train.csv')
train['label'] = 'train'
test = pd.read_csv('./data/test.csv')
test['label'] = 'prediction'

# %%
X_train = train.loc[:,['carat', 'cut_ord', 'clarity_ord']]
y_train = train.loc[:,['price']]

# %%
X_test = test.loc[:,['carat', 'cut_ord', 'clarity_ord']]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
test['price'] = y_pred

# %%
test.head()
# Out:
#    Unnamed: 0  carat        cut  cut_ord color clarity  clarity_ord  \
# 0           1   1.22    Premium        4     G     SI1            3
# 1           2   1.01       Good        2     G     VS2            5
# 2           3   0.71  Very Good        3     I     VS2            5
# 3           4   1.01      Ideal        5     D     SI2            2
# 4           5   0.27      Ideal        5     H    VVS2            6
#
#         label        price
# 0  prediction  6963.064946
# 1  prediction  5801.593908
# 2  prediction  3452.947494
# 3  prediction  4909.324218
# 4  prediction   551.603143

# %%
data = train.append(test, ignore_index=True)

# %%
fig = px.scatter(data_frame=data, x='carat', y='price', color='label', template='plotly_dark', title='Carat vs Price')
fig.show()
